# %% [markdown]
# # Searching for the category

# %% [markdown]
# For this code along we are only going to use the products DataFrame. However, if you believe there is information in other tables that can help to create categories, please feel free to explore.

# %%
import pandas as pd

# %%
# products_cl.csv
url = "https://drive.google.com/file/d/1s7Lai4NSlsYjGEPg1QSOUJobNYVsZBOJ/view?usp=sharing" 
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products_cl = pd.read_csv(path)

# %%
product_category_df = products_cl.copy()

# %%
product_category_df.head()
# Out:
#        sku                                           name  \
# 0  RAI0007              Silver Rain Design mStand Support
# 1  APP0023              Apple Mac Keyboard Keypad Spanish
# 2  APP0025               Mighty Mouse Apple Mouse for Mac
# 3  APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4  KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
#
#                                                 desc  price  in_stock  \
# 0       Aluminum support compatible with all MacBook  59.99         1
# 1          USB ultrathin keyboard Apple Mac Spanish.  59.00         0
# 2                             mouse Apple USB cable.  59.00         0
# 3              IPhone dock and USB Cable Apple iPod.  25.00         0
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99         1
#
#        type
# 0      8696
# 1  13855401
# 2      1387
# 3      1230
# 4      1364

# %% [markdown]
# ## 1.&nbsp; Category creation by search term
# Let's start by creating a column `category`. For now we'll fill this column with a blank string `""`.

# %%
product_category_df["category"] = ""
product_category_df.head()
# Out:
#        sku                                           name  \
# 0  RAI0007              Silver Rain Design mStand Support
# 1  APP0023              Apple Mac Keyboard Keypad Spanish
# 2  APP0025               Mighty Mouse Apple Mouse for Mac
# 3  APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4  KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
#
#                                                 desc  price  in_stock  \
# 0       Aluminum support compatible with all MacBook  59.99         1
# 1          USB ultrathin keyboard Apple Mac Spanish.  59.00         0
# 2                             mouse Apple USB cable.  59.00         0
# 3              IPhone dock and USB Cable Apple iPod.  25.00         0
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99         1
#
#        type category
# 0      8696
# 1  13855401
# 2      1387
# 3      1230
# 4      1364

# %% [markdown]
# We can find all the products with certain words in their `description` using `.loc[]` and `.str.contains()`. Here we'll look at all the items that have the word `keyboard` in their description.

# %%
product_category_df.loc[product_category_df["desc"].str.lower().str.contains("keyboard"), :]
# Out:
#             sku                                               name  \
# 1       APP0023                  Apple Mac Keyboard Keypad Spanish
# 15      MOS0021               Clearguard Moshi MacBook Pro and Air
# 24      APP0277         Apple Wireless Keyboard Keyboard (OEM) Mac
# 64      HGD0012            Henge Docks Click keyboard support iMac
# 365     LOG0084  Logitech Ultrathin Keyboard Cover Keyboard Cov...
# ...         ...                                                ...
# 9720    PAC2508  Replacement Magic Wireless Keyboard by Matias ...
# 9751    MTF0008               Mistify Clean Screens Natural 500ml.
# 9796  ZAG0026-A  Open - Zagg Rugged Keyboard Folio iPad Messeng...
# 9932    APP1472         Apple Magic Keyboard English International
# 9945  TWS0106-A  Open - Twelve South Bridge Magic Keyboard for ...
#
#                                                    desc   price  in_stock  \
# 1             USB ultrathin keyboard Apple Mac Spanish.   59.00         0
# 15    Keyboard Protector MacBook Pro 13-inch Retina ...   24.95         0
# 24    Ultrathin keyboard Apple Bluetooth Spanish (un...   79.00         0
# 64    Base to hold the Apple Magic TrackPad and Wire...   29.00         0
# 365   Ultrathin cover and cover with Bluetooth keybo...   89.99         0
# ...                                                 ...     ...       ...
# 9720  Keyboard replacement service at the time of pu...  119.99         1
# 9751              Spray cleaning screens and keyboards.   14.99         1
# 9796  Case reconditioned keyboard and adjustable pos...   99.99         0
# 9932  English keyboard Mac and Apple iPad Ultrathin ...  119.00         1
# 9945  Light reconditioned support to hold the Keyboa...   48.00         0
#
#           type category
# 1     13855401
# 15    13835403
# 24    13855401
# 64        8696
# 365   12575403
# ...        ...      ...
# 9720  13855401
# 9751  12085400
# 9796  12575403
# 9932  13855401
# 9945      8696
#
# [89 rows x 7 columns]

# %% [markdown]
# Next, we change the value in the category column to `keyboard` for all of these keyboard products.

# %%
product_category_df.loc[product_category_df["desc"].str.lower().str.contains("keyboard"), "category"] = "keyboard"

# %% [markdown]
# Let's take a look at the effect that had on the `category` column.

# %%
product_category_df["category"].value_counts()
# Out:
#             9903
# keyboard      89
# Name: category, dtype: int64

# %% [markdown]
# ## 2.&nbsp; Category creation using regex
# We can also use a product's `name` to select products for our categories.

# %%
product_category_df.loc[product_category_df["name"].str.lower().str.contains("apple iphone"), :]
# Out:
#             sku                                               name  \
# 35      APP0308  AV Cable Adapter Apple iPhone iPad and iPod white
# 214     REP0100               Color change to White Apple iPhone 4
# 215     REP0052               Color change to White Apple iPhone 4
# 579     APP0675                    Apple iPhone 5S 32GB Space Gray
# 956     APP0823                         Apple iPhone 6 16GB Silver
# ...         ...                                                ...
# 9790    AP20455               Like new - Apple iPhone 8 256GB Gold
# 9794  APP2482-A              Open - Apple iPhone 8 Plus 256GB Gold
# 9929  APP2477-A         Open - Apple iPhone 8 Plus 64GB Space Gray
# 9958    AP20467  Like new - Apple iPhone Silicone Case Cover 7 ...
# 9969    AP20468       Like new - Apple iPhone Black Lightning Dock
#
#                                                    desc    price  in_stock  \
# 35               IPhone iPad iPod adapter and AV cable.    45.00         0
# 214                   It is including parts and labor..    94.21         0
# 215                   It is including parts and labor..    94.21         0
# 579               New Free iPhone 5S 32GB (ME435Y / A).   559.00         0
# 956               New iPhone 6 16GB Free (MG482QL / A).   639.00         0
# ...                                                 ...      ...       ...
# 9790  Apple iPhone 8 reconditioned 256GB in Gold rea...   979.00         0
# 9794    Refurbished Apple iPhone 8 Plus 256GB Free Gold  1089.00         0
# 9929                Apple iPhone 8 Plus 64GB Space Gray   919.00         0
# 9958  Reconditioned silicone sleeve microfiber Apple...    45.00         0
# 9969  Support base and refitted with dock connector ...    59.00         0
#
#            type category
# 35         1230
# 214    1,44E+11
# 215    1,44E+11
# 579         NaN
# 956         NaN
# ...         ...      ...
# 9790  113291716
# 9794  113281716
# 9929  113281716
# 9958   11865403
# 9969   13615399
#
# [424 rows x 7 columns]

# %% [markdown]
# Looks like we get a lot of accessories included in this search. We can refine this using a little regex. Here, we will add `.{0,7}` at the beginning of the search: this means we will find all `apple iphone`s that have 7 or less characters preceding the term "apple iphone" - if there's 8 characters preceding the search term, it won't be found. This should help refine our search by using the nomenclature of the DataFrame to our advantage.
#
# If you feel unsure about regex, please use [regex101](https://regex101.com/). It's really useful for checking your code, and parts of other people's code that you're unsure about.

# %%
product_category_df.loc[product_category_df["name"].str.lower().str.contains("^.{0,7}apple iphone"), :]
# Out:
#             sku                                        name  \
# 579     APP0675             Apple iPhone 5S 32GB Space Gray
# 956     APP0823                  Apple iPhone 6 16GB Silver
# 961     APP0829             Apple iPhone 6 Plus 16GB Silver
# 962     APP0822              Apple iPhone 6 16GB Space Gray
# 963     APP0825              Apple iPhone 6 64GB Space Gray
# ...         ...                                         ...
# 9585  APP1634-A       Open - Apple iPhone 7 Plus 32GB Black
# 9587  APP2540-A    Open - Apple iPhone Leather Folio X Baya
# 9714  APP2562-A  Open - Apple iPhone Leather Case Cover Red
# 9794  APP2482-A       Open - Apple iPhone 8 Plus 256GB Gold
# 9929  APP2477-A  Open - Apple iPhone 8 Plus 64GB Space Gray
#
#                                                    desc   price  in_stock  \
# 579               New Free iPhone 5S 32GB (ME435Y / A).   559.0         0
# 956               New iPhone 6 16GB Free (MG482QL / A).   639.0         0
# 961           New iPhone 6 Plus 16G Free (MGA92QL / A).   749.0         0
# 962               New iPhone 6 16GB Free (MG472QL / A).   639.0         0
# 963               New iPhone 6 64GB Free (MG4F2QL / A).   749.0         0
# ...                                                 ...     ...       ...
# 9585            New 32GB Apple iPhone 7 Plus Free Black   779.0         0
# 9587     Leather case with box and official cover Apple   109.0         0
# 9714  Reconditioned skin sheath official Apple desig...    45.0         0
# 9794    Refurbished Apple iPhone 8 Plus 256GB Free Gold  1089.0         0
# 9929                Apple iPhone 8 Plus 64GB Space Gray   919.0         0
#
#            type category
# 579         NaN
# 956         NaN
# 961         NaN
# 962         NaN
# 963         NaN
# ...         ...      ...
# 9585   85651716
# 9587   11865403
# 9714   11865403
# 9794  113281716
# 9929  113281716
#
# [269 rows x 7 columns]

# %% [markdown]
# Now we can use the same trick as before to set the category - selecting the `category` column and setting it to the string of our choice.

# %%
product_category_df.loc[product_category_df["name"].str.lower().str.contains("^.{0,7}apple iphone"), "category"] = "smartphone"

# %%
product_category_df["category"].value_counts()
# Out:
#               9634
# smartphone     269
# keyboard        89
# Name: category, dtype: int64

# %% [markdown]
# ## 3.&nbsp; One product with multiple categories
# A product may fit into multiple categories. To help us create multiple categories for one product, we will use the python addition assignment `+=`. The addition assignment is a shorthand way to add something (number, string, etc...) to a variable without changing the variable name.
#
# Let's have a look at a couple of examples.

# %%
a = 10
a = a + 5
a
# Out:
# 15

# %%
a = 10
a += 5
a
# Out:
# 15

# %%
b = "Tyrannosaurus"
b = b + " rex"
b
# Out:
# 'Tyrannosaurus rex'

# %%
b = "Tyrannosaurus"
b += " rex"
b
# Out:
# 'Tyrannosaurus rex'

# %% [markdown]
# Now let's look at how this can help us in our category creation.
#
# First, we'll reset all the values in the category column to an empty string `""`.

# %%
product_category_df["category"] = ""

# %% [markdown]
# Now, let's create some categories and utilise the addition assignment.

# %%
product_category_df.loc[product_category_df["desc"].str.lower().str.contains("keyboard"), "category"] += ", keyboard"
product_category_df.loc[product_category_df["name"].str.lower().str.contains("^.{0,7}apple iphone"), "category"] += ", smartphone"
product_category_df.loc[product_category_df["name"].str.lower().str.contains("^.{0,7}apple ipod"), "category"] += ", ipod"
product_category_df.loc[product_category_df["name"].str.lower().str.contains("^.{0,7}apple ipad|tablet"), "category"] += ", tablet"
product_category_df.loc[product_category_df["name"].str.lower().str.contains("imac|mac mini|mac pro"), "category"] += ", desktop"

# %%
product_category_df["category"].value_counts()
# Out:
#                        8362
# , desktop               923
# , tablet                307
# , smartphone            269
# , keyboard               83
# , ipod                   42
# , keyboard, tablet        4
# , keyboard, desktop       2
# Name: category, dtype: int64

# %%
product_category_df
# Out:
#           sku                                           name  \
# 0     RAI0007              Silver Rain Design mStand Support
# 1     APP0023              Apple Mac Keyboard Keypad Spanish
# 2     APP0025               Mighty Mouse Apple Mouse for Mac
# 3     APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4     KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...       ...                                            ...
# 9987  BEL0376        Belkin Travel Support Apple Watch Black
# 9988  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 9989  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 9990  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 9991  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                    desc  price  in_stock  \
# 0          Aluminum support compatible with all MacBook  59.99         1
# 1             USB ultrathin keyboard Apple Mac Spanish.  59.00         0
# 2                                mouse Apple USB cable.  59.00         0
# 3                 IPhone dock and USB Cable Apple iPod.  25.00         0
# 4     2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99         1
# ...                                                 ...    ...       ...
# 9987  compact and portable stand vertically or horiz...  29.99         1
# 9988  Backpack with capacity of 14 liter compartment...  69.95         1
# 9989  Backpack with capacity of 14 liter compartment...  69.95         1
# 9990  Backpack with capacity of 14 liter compartment...  69.95         0
# 9991  Backpack with capacity of 14 liter compartment...  69.95         1
#
#           type    category
# 0         8696
# 1     13855401  , keyboard
# 2         1387
# 3         1230
# 4         1364
# ...        ...         ...
# 9987     12282
# 9988      1392
# 9989      1392
# 9990      1392
# 9991      1392
#
# [9992 rows x 7 columns]

# %% [markdown]
# As you can see, some products now have 2 categories instead of just one. At the end, you can use your skills with string to tidy up the opening comma and space in the `category` column.

# %% [markdown]
# # Challenge. Your categories
# Now it's your turn. We'll reset the Dataframe so that no categories exist, and it's up to you to create the categories based on keywords in the name and description. Feel free to go wild and make as many categories as you like.
# * Remember you can also use regex to refine your searches.
# * Remember you can use the or operator `|` to search for multiple terms at once.
# * Remember to tidy up any untidy strings at the end.

# %%
# your code here

# %% [markdown]
# ## 4.&nbsp; [BONUS] Using `type` to create categories
# There could be another way to create categories, but this one you'll have to explore this one alone.
#
# We have the mysterious column `type` in the `products` table. This could potentially be ready-made categories labelled with numbers instead of words. Let's investigate.

# %%
category_type_df = products_cl.copy()

# %% [markdown]
# Here are the `type`s that have the most products.

# %%
category_type_df.groupby("type").count().nlargest(10, "sku")
# Out:
#            sku  name  desc  price  in_stock
# type
# 11865403  1057  1057  1057   1057      1057
# 12175397   939   939   939    939       939
# 1298       783   783   783    783       783
# 11935397   562   562   562    562       562
# 11905404   454   454   454    454       454
# 1282       373   373   373    373       373
# 12635403   362   362   362    362       362
# 13835403   269   269   269    269       269
# 5,74E+15   247   247   247    247       247
# 1364       216   216   216    216       216

# %%
product_category_df.loc[product_category_df["type"] == "51601716"]
# Out:
#             sku                                           name  \
# 3869    APP1481                   Apple iPhone 64GB Space Gray
# 3872    APP1484                    Apple iPhone 64GB Rose Gold
# 4519    IFX0089  iFixit piece Home button iPhone 5s Space Gray
# 6728    APP1966                       Apple iPhone 32GB Silver
# 6729    APP1968                         Apple iPhone 32GB Gold
# 6730    APP1967                   Apple iPhone SE 128GB Silver
# 6731    APP1969                     Apple iPhone SE 128GB Gold
# 6732    APP1970                   Apple iPhone 32GB Space Gray
# 6734    APP1971               Apple iPhone SE 128GB Space Gray
# 6735    APP1972                    Apple iPhone 32GB Rose Gold
# 6736    APP1973                Apple iPhone SE 128GB Rose Gold
# 6854    APP2036  Open - Apple iPhone 64 GB Space Gray - As new
# 6857    APP2037         Like new - Apple iPhone 16 GB Oro Rosa
# 6859    APP2038  Open - Apple iPhone 16 GB Oro Rosa - like new
# 7028    PAC2051            Second hand - iPhone 5S 16GB Silver
# 7029    PAC2052              Second hand - iPhone 5s 16GB Gold
# 7030    PAC2053        Second hand - iPhone 5s 16GB Space Gray
# 7126    AP20103        Like new - Apple iPhone 64GB Space Gray
# 7127    AP20132            Like new - Apple iPhone 64GB Silver
# 7128    AP20163         Like new - Apple iPhone 64GB Rose Gold
# 7129    AP20165        Like new - Apple iPhone 16GB Space Gray
# 7131    AP20166              Like new - Apple iPhone 16GB Gold
# 7137    AP20189         Open - Apple iPhone 5s 16GB Space Gray
# 7139    AP20190             Open - Apple iPhone 5S 16GB Silver
# 7924    AP20258            Like new - Apple iPhone 16GB Silver
# 7941    AP20259              Like new - Apple iPhone 64GB Gold
# 7981    AP20266               Like New - iPhone 5S 16GB Silver
# 7982    AP20267           Like New - iPhone 5s 16GB Space Gray
# 7992    AP20257         Like new - Apple iPhone 16GB Rose Gold
# 8049  APP1966-A             Open - Apple iPhone 32GB Rose Gold
# 8150    AP20307        Like new - Apple iPhone 32GB Space Gray
# 8151    AP20310    Like new - Apple iPhone SE 128GB Space Gray
# 8152    AP20305         Like new - Apple iPhone 32GB Rose Gold
# 8153    AP20306            Like new - Apple iPhone 32GB Silver
# 8154    AP20308          Like new - Apple iPhone SE 128GB Gold
# 8155    AP20309     Like new - Apple iPhone SE 128GB Rose Gold
# 8717    AP20057     Like new - Apple iPhone 5s 16GB Space Gray
# 8863  APP1961-A        Like new - Apple iPhone SE 128GB Silver
# 8983    AP20374        Like new - Apple iPhone SE 128GB Silver
# 8985    AP20055         Like new - Apple iPhone 5S 16GB Silver
# 9253    AP20413              Like new - Apple iPhone 32GB Gold
# 9277    AP20370        Like new - Apple iPhone SE 128GB Silver
# 9494  APP1960-A                Open - Apple iPhone 32GB Silver
#
#                                                    desc   price  in_stock  \
# 3869       New iPhone SE with 4-inch screen 64 free GB.  549.00         0
# 3872       New iPhone SE with 4-inch screen 64 free GB.  549.00         0
# 4519   Piece Home button for unlocking and iPhone 5s on   29.95         1
# 6728       New iPhone SE with 4-inch screen 32 free GB.  419.00         1
# 6729       New iPhone SE with 4-inch screen 32 free GB.  419.00         0
# 6730              New iPhone screen 4-inch 128 GB free.  529.00         1
# 6731              New iPhone screen 4-inch 128 GB free.  529.00         1
# 6732       New iPhone SE with 4-inch screen 32 free GB.  419.00         0
# 6734              New iPhone screen 4-inch 128 GB free.  529.00         0
# 6735       New iPhone SE with 4-inch screen 32 free GB.  419.00         1
# 6736              New iPhone screen 4-inch 128 GB free.  529.00         1
# 6854     Free Apple iPhone 64GB Space Gray (MLM62Y / A)  549.00         0
# 6857  Apple iPhone SE Free Refurbished 16GB Rose Gol...  489.00         0
# 6859       Apple iPhone 16GB Free Oro Rosa (MLXN2Y / A)  489.00         0
# 7028  Free Apple iPhone 5s 16GB Color Silver Recondi...  409.00         0
# 7029   Apple iPhone 5s 16GB Second Hand Free Color Gold  409.00         0
# 7030  Apple iPhone 5s 16GB Second Hand Free Color Gr...  409.00         0
# 7126   Apple iPhone SE Free Refurbished 64GB Space Gray  549.00         0
# 7127  Apple iPhone SE Free Refurbished 64GB Color Si...  549.00         0
# 7128  Refurbished Apple iPhone 64GB Free Rose Gold C...  549.00         0
# 7129   Apple iPhone SE Free Refurbished 16GB Space Gray  489.00         0
# 7131   Apple iPhone SE Free Refurbished 16GB Color Gold  489.00         0
# 7137  Refurbished Apple iPhone 5s 16GB Free Color Gr...  409.00         0
# 7139    Apple iPhone 5s 16GB refitted Free Color Silver  409.00         0
# 7924  Apple iPhone SE Free Refurbished 16GB Color Si...  489.00         0
# 7941                 Refurbished 64GB iPhone gold color  549.00         0
# 7981  Free Apple iPhone 5s 16GB Color Silver Recondi...  409.00         0
# 7982   Apple iPhone 5s 16GB Free refitted in Gray Space  409.00         0
# 7992                  Refurbished 16GB iPhone pink gold  489.00         0
# 8049         iPhone open but like new 32GB in pink gold  419.00         0
# 8150   iPhone SE reconditioned 4 inch screen 32 free GB  419.00         0
# 8151         iPhone SE reconditioned 4 inch 128 free GB  529.00         0
# 8152            Refurbished 32GB iPhone rose gold color  419.00         0
# 8153   iPhone SE reconditioned 4 inch screen 32 free GB  419.00         0
# 8154          iPhone SE reconditioned 4 inch Free 128GB  529.00         0
# 8155          iPhone SE reconditioned 4 inch Free 128GB  529.00         0
# 8717  iPhone 5S 16GB state as new and completely rev...  409.00         0
# 8863  iPhone SE open but as new with 4 inch 128 GB f...  529.00         0
# 8983        iPhone SE reconditioned 4 inch 128 GB free.  529.00         0
# 8985    IPhone 5S refitted and ready to use 16GB Silver  409.00         0
# 9253           SE iPhone with 4-inch screen 32 free GB.  419.00         0
# 9277          iPhone SE reconditioned 4 inch Free 128GB  529.00         0
# 9494  iPhone SE reconditioned 4 inch screen 32 free GB.  419.00         0
#
#           type      category
# 3869  51601716  , smartphone
# 3872  51601716  , smartphone
# 4519  51601716
# 6728  51601716  , smartphone
# 6729  51601716  , smartphone
# 6730  51601716  , smartphone
# 6731  51601716  , smartphone
# 6732  51601716  , smartphone
# 6734  51601716  , smartphone
# 6735  51601716  , smartphone
# 6736  51601716  , smartphone
# 6854  51601716  , smartphone
# 6857  51601716
# 6859  51601716  , smartphone
# 7028  51601716
# 7029  51601716
# 7030  51601716
# 7126  51601716
# 7127  51601716
# 7128  51601716
# 7129  51601716
# 7131  51601716
# 7137  51601716  , smartphone
# 7139  51601716  , smartphone
# 7924  51601716
# 7941  51601716
# 7981  51601716
# 7982  51601716
# 7992  51601716
# 8049  51601716  , smartphone
# 8150  51601716
# 8151  51601716
# 8152  51601716
# 8153  51601716
# 8154  51601716
# 8155  51601716
# 8717  51601716
# 8863  51601716
# 8983  51601716
# 8985  51601716
# 9253  51601716
# 9277  51601716
# 9494  51601716  , smartphone

# %% [markdown]
# Let's have a look at the first `type` to see if we can make categories from this column.

# %%
category_type_df.loc[category_type_df["type"] == "11865403", :].sample(10)
# Out:
#           sku                                               name  \
# 3096  OTT0102  OtterBox iPhone Case My Symmetry 6 / 6s Transp...
# 9807  MOP0113  Mophie Juice Pack Air Battery Case iPhone 8/7 ...
# 4822  LIF0112  LifeProof Fre Submersible Case iPhone 5 / 5S B...
# 8234  SPE0201  IPhone Case Speck Presidio Show 8 Plus / 7 Plu...
# 2530  APP1155  Case Apple iPhone 6 Plus / 6s Plus Silicone Ca...
# 3156  SNA0058  Sena UltraSlim Case Heritage iPhone 6 / 6S / 7...
# 6654  THU0045                 Thule Atmos X3 Case Black iPhone 7
# 5218  APP1687      Apple iPhone Leather Case Cover 7 Brown Candy
# 6908  GRT0462  Griffin Survivor iPhone Case Clear 8 Plus / 7 ...
# 5261  TUC0289  Tucano ELEKTRO FLEX UltraSlim Case iPhone 7 Pl...
#
#                                                    desc  price  in_stock  \
# 3096  Protective housing with rear transparent and c...  29.99         0
# 9807  Mophie Juice Pack Air Case with battery for Ap...  99.95         1
# 4822  waterproof and extreme conditions Case for iPh...  79.99         1
# 8234  protective case with anti-impact polycarbonate...  29.95         0
# 2530  Ultrathin silicone case and microfiber premium...  45.00         0
# 3156           ultra thin skin iPhone 6 / 6s and 7 Case  39.95         0
# 6654  resistant sheath with adhesive inner material ...  29.95         0
# 5218  ultrathin leather case and microfiber premium ...  55.00         0
# 6908  Case, Green / Transparent iPhone resistant pol...  24.99         0
# 5261  thin flexible sleeve with metallic shades for ...  19.90         0
#
#           type
# 3096  11865403
# 9807  11865403
# 4822  11865403
# 8234  11865403
# 2530  11865403
# 3156  11865403
# 6654  11865403
# 5218  11865403
# 6908  11865403
# 5261  11865403

# %% [markdown]
# Looks like this is a category of phone cases.
#
# Let's have a look at the 2nd largest type to see if that's also a clear category.

# %%
category_type_df.loc[category_type_df["type"] == "12175397", :].sample(10)
# Out:
#           sku                                               name  \
# 8496  PAC2403  DS418play Synology NAS Server | 10GB RAM | 8TB...
# 1650  QNA0077                       QNAP TS-431 + NAS Mac and PC
# 2941  PAC1172              Synology DS416 Pack | WD 24TB Network
# 4391  SYN0140  Synology DS716 + II | 2GB RAM Mac and PC Serve...
# 8648  PAC2429  Synology DS918 + NAS Server | 8GB RAM | 8TB (4...
# 7767  PAC1696  Pack QNAP TS-251A NAS Server | 16GB RAM | Seag...
# 5934  PAC1752                                   QNAP TS-231P NAS
# 8471  PAC2254  DS418play Synology NAS Server | 10GB RAM | 24T...
# 8804  SYN0186              Synology NAS Server DS218J Mac and PC
# 4413  PAC1846  Synology DS716 + II | 8GB RAM | 12TB (2x6TB) S...
#
#                                                    desc    price  in_stock  \
# 8496  4-bay NAS server to accommodate 4K Ultra HD files  1041.31         0
# 1650                Four-bay NAS Server for Mac and PC.   398.09         0
# 2941  Synology DS416 + Pack 24TB (4x6TB) Network WD ...  1405.99         0
# 4391  2-bay NAS server and 2GB of RAM for Mac iPad a...   471.90         0
# 8648  NAS server of the Plus Series for companies se...  1076.94         0
# 7767  NAS with 16GB of RAM and 8 TB (2x4TB) Seagate ...   851.65         0
# 5934  NAS 6TB capacity Seagate Hard Drives for Mac a...   496.57         0
# 8471  4-bay NAS server to accommodate 4K Ultra HD files  1621.35         0
# 8804  2-bay NAS server basic to back domestic securi...   185.99         1
# 4413  Synology DS716 + II with 8GB RAM memory + 12TB...  1111.87         0
#
#           type
# 8496  12175397
# 1650  12175397
# 2941  12175397
# 4391  12175397
# 8648  12175397
# 7767  12175397
# 5934  12175397
# 8471  12175397
# 8804  12175397
# 4413  12175397

# %% [markdown]
# Looks like this category is full of servers.
#
# I wonder how many `type`s account for most of our products?

# %%
n = 30
print(f"With the {n} largest types, we account for {((category_type_df.groupby('type').count().nlargest(n, 'sku')['sku'].sum()) / (category_type_df.shape[0]) * 100).round(2)}% of all products.")
# Out:
# With the 30 largest types, we account for 78.4% of all products.

# %% [markdown]
# Looks like we can simply investigate 30 types and set the categories, then the remaining 20% of products can have the category `other`.
#
# Use the skills you learnt above to change the category for each type.

# %%
n = 30
category_type_df.groupby('type').count().nlargest(n,'sku')
# Out:
#            sku  name  desc  price  in_stock
# type
# 11865403  1057  1057  1057   1057      1057
# 12175397   939   939   939    939       939
# 1298       783   783   783    783       783
# 11935397   562   562   562    562       562
# 11905404   454   454   454    454       454
# 1282       373   373   373    373       373
# 12635403   362   362   362    362       362
# 13835403   269   269   269    269       269
# 5,74E+15   247   247   247    247       247
# 1364       216   216   216    216       216
# 12585395   190   190   190    190       190
# 1296       187   187   187    187       187
# 1325       183   183   183    183       183
# 5384       178   178   178    178       178
# 1433       171   171   171    171       171
# 12215397   170   170   170    170       170
# 5398       159   159   159    159       159
# 1,02E+12   130   130   130    130       130
# 1,44E+11   129   129   129    129       129
# 57445397   129   129   129    129       129
# 1334       115   115   115    115       115
# 2158       107   107   107    107       107
# 2449       107   107   107    107       107
# 12655397   105   105   105    105       105
# 1229       104   104   104    104       104
# 12995397    95    95    95     95        95
# 1515        85    85    85     85        85
# 13615399    78    78    78     78        78
# 13555403    75    75    75     75        75
# 1405        75    75    75     75        75

# %%
def label_race (row):
   if row['eri_hispanic'] == 1 :
      return 'Hispanic'
   if row['eri_afr_amer'] + row['eri_asian'] + row['eri_hawaiian'] + row['eri_nat_amer'] + row['eri_white'] > 1 :
      return 'Two Or More'
   if row['eri_nat_amer'] == 1 :
      return 'A/I AK Native'
   if row['eri_asian'] == 1:
      return 'Asian'
   if row['eri_afr_amer']  == 1:
      return 'Black/AA'
   if row['eri_hawaiian'] == 1:
      return 'Haw/Pac Isl.'
   if row['eri_white'] == 1:
      return 'White'
   return 'Other'

# %%
oolpb_m.loc[oolpb_m['type'] == '11865403', 'category'] = "Phone Leather cases"

# %%
if category_type_df.loc[category_type_df['type']] == '11865403':
                        return 'Phone Leather cases'
# Out:
#   File "<ipython-input-38-41547011402e>", line 2
#     return 'Phone Leather cases'
#     ^
# SyntaxError: 'return' outside function
